# %% [markdown]
# <a href="https://colab.research.google.com/github/shazzad-hasan/experiments/blob/main/law_of_large_numbers/fair_coins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import default_rng

# %%
class Coin:
    def __init__(self, weight = 0.5):
        self.weight = weight
        self.outcomes = np.array([])
    
    def flip(self, N: int = 1):
        rng = default_rng()
        vals = rng.integers(low=0, high=10, size=N)
        self.outcomes = np.append(self.outcomes, np.where(vals >= 10*self.weight, 0, 1))

    def n_heads(self, flips):
        return int(np.sum(self.outcomes[:flips]))
    
    def n_tails(self, flips):
        return int(len(self.outcomes[:flips]) - np.sum(self.outcomes[:flips]))

coin = Coin()

# %%
N = 10
coin.flip(N)

heads = [coin.n_heads(i) for i in range(1, N+1)]
frac_heads = np.array(heads)/np.array([i for i in range(1, N+1)])
tails = np.array([coin.n_tails(i) for i in range(1, N+1)])
frac_tails = np.array(tails)/np.array([i for i in range(1, N+1)])

fig = plt.figure()
ax = plt.axes()
x = np.linspace(1, N, N)
ax.plot(x, frac_heads, '.', label='Heads');
ax.plot(x, frac_tails, '.', label='Tails');
ax.set_title(f"{N} Flips")
ax.set_ylabel("Fraction of Heads / Tails")
ax.set_xlabel("Flips")
fig.legend(['Heads', 'Tails'], loc='upper right')
plt.show()

# %%
sample_sizes = [10, 100, 1000, 2000, 4000, 10000]

fig, ax = plt.subplots(2, 3, sharex=False, sharey=True, figsize=(14, 10))
for i, N in enumerate(sample_sizes):
    if i < 3: j = 0
    else: j = 1

    coin.flip(N)

    heads = [coin.n_heads(i) for i in range(1, N+1)]
    frac_heads = np.array(heads)/np.array([i for i in range(1, N+1)])
    tails = np.array([coin.n_tails(i) for i in range(1, N+1)])
    frac_tails = np.array(tails)/np.array([i for i in range(1, N+1)])

    ax[j, i - j*3].plot(np.linspace(1, N, N), frac_heads, '.', label='Heads')
    ax[j, i - j*3].plot(np.linspace(1, N, N), frac_tails, '.', label='Tails')
    
    ax[j, i - j*3].set_title(f"{N} flips")
    ax[j, i - j*3].set_ylabel("Fraction of Heads / Tails")
    ax[j, i - j*3].set_xlabel("Flips")

fig.legend(['Heads', 'Tails'], loc='upper right')
plt.show()
